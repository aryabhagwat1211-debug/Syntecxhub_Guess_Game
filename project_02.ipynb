# %%
import random 
num = random.randint(1,100)
print("Computer selected a number from 1 to 100 (inclusive), now it's your turn")
turns = 0
while True:
    guess = int(input("Enter the guessed number : "))
    if (guess==num):
        print("You got it right")
        break
    elif (guess<num):
        print("Bigger number please")
        turns+=1
    elif (guess>num):
        print("Lesser number please")
        turns +=1 
print("Number of turns = ",turns+1)
# Out:
# Computer selected a number from 1 to 100 (inclusive), now it's your turn
# Lesser number please
# Bigger number please
# Lesser number please
# Lesser number please
# Bigger number please
# You got it right
# Number of turns =  6
